# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..", "..")))
import pytorch_training_header
# Out:
# |----------------------------------------------------------------------------------------------------|
# | CUDA Available: True
# | PyTorch Version: 2.10.0.dev20251124+cu128
# | CUDA Version: 12.8
# | Supported Archs: ['sm_70', 'sm_75', 'sm_80', 'sm_86', 'sm_90', 'sm_100', 'sm_120']
# | Using CUDA Memory Fraction: 0.8
# |----------------------------------------------------------------------------------------------------|
